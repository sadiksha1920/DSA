# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiksha1920/DSA/blob/master/day7_KNN(2_18).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import accuracy_score, mean_squared_error
import matplotlib.pyplot as plt

# %%
#data
data ={
    'hours_studied':[1,2,3,4,5,6,7,8],
    'passed':[0,0,0,0,1,1,1,1]
}
df= pd.DataFrame(data)

# %%
X= df[["hours_studied"]]
y= df["passed"]

# %%
#data split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
#feature scaling
scalar = StandardScaler()
X_train_scaled = scalar.fit_transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %%
#Choose K and create modle
knn= KNeighborsClassifier(n_neighbors=3, metric='euclidean')
knn.fit(X_train_scaled,y_train) #(store training data)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
#predict
y_pred = knn.predict(X_test_scaled)

# %%
# Step 6: Evaluate
print("Predictions:,y_pred")
print("Accuracy:", accuracy_score(y_test,y_pred))
# Out:
# Predictions:,y_pred
# Accuracy: 1.0

# %%
#Visualization
plt.scatter(X['hours_studied'],y, c=y,cmap='coolwarm',s=100)
plt.xlabel('Hours Studied')
plt.ylabel("Passed(1)/Failed(0)")
plt.title("KNN Example")
plt.show()

# %% [markdown]
# KNN for Regression

# %%
#data
data={
    'hours_studied':[1,2,3,4,5,6,7,8],
    'score':[10,20,25,40,45,55,60,65]
}

df = pd.DataFrame(data)
X = df[['hours_studied']]
y = df['score']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
#Scale features
scalar = StandardScaler()
X_train_scaled = scalar.fit_transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %%
#KNN Regressor
knn_reg = KNeighborsRegressor(n_neighbors=3)
knn_reg.fit(X_train_scaled,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)
