# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiksha1920/DSA/blob/master/day23DL_LOSS_FUNCTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# Binary cross-entropy

# %%
#Data
X_train = np.random.rand(200,10)
y_train = np.random.randint(0,2,200)

#Model
model = Sequential([
    Dense(16, activation='relu', input_shape=(10,)),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy']
              )
model.fit(X_train,y_train,epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5100 - loss: 0.7272
# Epoch 2/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5100 - loss: 0.7160
# Epoch 3/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5100 - loss: 0.7075
# Epoch 4/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5250 - loss: 0.7012
# Epoch 5/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5200 - loss: 0.6972

# %%
from tensorflow.keras.utils import to_categorical

#Data
X_train = np.random.rand(300,10)
y= np.random.randint(0,3,300)  #3 classes
y_train = to_categorical(y,num_classes=3)
#Model
model = Sequential([
    Dense(16, activation='relu', input_shape=(10,)),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy']
              )
model.fit(X_train,y_train,epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3567 - loss: 1.1207
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3400 - loss: 1.1179
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3600 - loss: 1.1147
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3667 - loss: 1.1128
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3600 - loss: 1.1114

# %%
from tensorflow.keras.losses import Huber

#Data
X_train = np.random.rand(200,10)
y_train = np.random.rand(200) #continue values

#Model
model = Sequential([
    Dense(16, activation='relu', input_shape=(10,)),
    Dense(1) #linear output
])

model.compile(optimizer='adam',
              loss=Huber(),
              metrics=['mae']
              )
model.fit(X_train,y_train,epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5671 - mae: 1.0482
# Epoch 2/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4765 - mae: 0.9452
# Epoch 3/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3973 - mae: 0.8492
# Epoch 4/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3317 - mae: 0.7637
# Epoch 5/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2760 - mae: 0.6850

# %%
from tensorflow.keras.losses import CosineSimilarity

#Data
X_train = np.random.rand(200,20)
y_train = np.random.rand(200,8) #vector values

#Model
model = Sequential([
    Dense(16, activation='relu', input_shape=(20,)),
    Dense(8)
])

model.compile(optimizer='adam',
              loss=CosineSimilarity(axis=1)

              )
model.fit(X_train,y_train,epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: -0.0142
# Epoch 2/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.2016
# Epoch 3/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.3464
# Epoch 4/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.4578
# Epoch 5/5
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.5454
