# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiksha1920/DSA/blob/master/001pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#creating series with list
l=[1,2,3,4,5]
s= pd.Series(l)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#we can also change the index of series by
l=[1,2,3,4,5]
s=pd.Series(l,index=['a','b','c','d','e'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#creating Series with Array
import numpy as np
a= np.array([80,20,78])
s=pd.Series(a)
s
# Out:
# 0    80
# 1    20
# 2    78
# dtype: int64

# %%
#creating series with dictionary
d={'name':'sadiksha','roll':1,'age':22}
s=pd.Series(d)
s
# Out:
# name    sadiksha
# roll           1
# age           22
# dtype: object

# %% [markdown]
# Attribute for Series

# %%
s= pd.Series(['sadiksha','binita','Garima','shiwani'],index=['a','b','c','d'])
s
# Out:
# a    sadiksha
# b      binita
# c      Garima
# d     shiwani
# dtype: object

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s.array
# Out:
# <NumpyExtensionArray>
# ['sadiksha', 'binita', 'Garima', 'shiwani']
# Length: 4, dtype: object

# %%
#using dtype attributes  gives what is the data type of element of this series
s.dtype
# Out:
# dtype('O')

# %%
#using values attribute 9returns values of series in numpy array
s.values
# Out:
# array(['sadiksha', 'binita', 'Garima', 'shiwani'], dtype=object)

# %%
#using shape attribute (for series shape 4 represent the 4 rows)
#for series s.shape also help us to find the numbers of elements in the series like s.size
s.shape
# Out:
# (4,)

# %%
s.ndim
# Out:
# 1

# %%
s.size #total number of element
# Out:
# 4

# %%
s.empty
# Out:
# False

# %%
s
# Out:
# a    sadiksha
# b      binita
# c      Garima
# d     shiwani
# dtype: object

# %%
s['a']
# Out:
# 'sadiksha'

# %%
s.at['a']
# Out:
# 'sadiksha'

# %%
s.iat[0] #we have to pass index
# Out:
# 'sadiksha'

# %%
s.iat[3]
# Out:
# 'shiwani'

# %% [markdown]
# Mathematical operation in Series

# %%
a=[1,2,3]
b=[2,3,4]
c=a+b
c
# Out:
# [1, 2, 3, 2, 3, 4]

# %%
import pandas as pd
s1=pd.Series([1,2,3])
s2=pd.Series([2,3,4])

# %%
#add
s1+s2
# Out:
# 0    3
# 1    5
# 2    7
# dtype: int64

# %%
s1-s2
# Out:
# 0   -1
# 1   -1
# 2   -1
# dtype: int64

# %%
s1*s2
# Out:
# 0     2
# 1     6
# 2    12
# dtype: int64

# %%
s1/s2
# Out:
# 0    0.500000
# 1    0.666667
# 2    0.750000
# dtype: float64

# %%
s1**s2
# Out:
# 0     1
# 1     8
# 2    81
# dtype: int64

# %%
s1>s2
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
s1==s2
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
s.dtype
# Out:
# dtype('O')

# %% [markdown]
# Getting value from the series

# %%
import pandas as pd
s= pd.Series([1,2,3,4,6])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    6
# dtype: int64

# %%
print(s[3]) # getting index 3 value
# Out:
# 4

# %%
s[1:3]# getting index 1 and 2 element
# Out:
# 1    2
# 2    3
# dtype: int64

# %%
s.index=['a','b','c','d','e']
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    6
# dtype: int64

# %%
print(s['d'])
# Out:
# 4

# %% [markdown]
# B) DataFrame - Data Frame is the 2D Data Structure (tabluar form)
# Different ways of Creating Data Frame in pandas
#
# By reading data from Excel File
#
# By reading data from CSV File (comma seperated values)
#
# BY using Dictionary

# %%
#making dataframe by reading excel
df=pd.read_excel(r"/content/excel_df.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1538/1562274631.py in <cell line: 0>()
#       1 #making dataframe by reading excel
# ----> 2 df=pd.read_excel(r"/content/excel_df.xlsx")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/excel_df.xlsx'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1538/1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
#making dataframe by reading csv
df=pd.read_csv(r"/content/new_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1538/2318581125.py in <cell line: 0>()
#       1 #making dataframe by reading csv
# ----> 2 df=pd.read_csv(r"/content/new_data.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/new_data.csv'

# %%
#making dataframe by using dictionary
dict ={'name':['sadiksha','garima','binita','sita','gita'],'roll':[1,2,3,4,5],'age':[13,14,15,23,24]}
df=pd.DataFrame(dict)
df
# Out:
#        name  roll  age
# 0  sadiksha     1   13
# 1    garima     2   14
# 2    binita     3   15
# 3      sita     4   23
# 4      gita     5   24

# %%
df
# Out:
#        name  roll  age
# 0  sadiksha     1   13
# 1    garima     2   14
# 2    binita     3   15
# 3      sita     4   23
# 4      gita     5   24

# %%
df.T
# Out:
#              0       1       2     3     4
# name  sadiksha  garima  binita  sita  gita
# roll         1       2       3     4     5
# age         13      14      15    23    24

# %%
df
# Out:
#        name  roll  age
# 0  sadiksha     1   13
# 1    garima     2   14
# 2    binita     3   15
# 3      sita     4   23
# 4      gita     5   24

# %%
print(df.at[1,'name']) # use label and get single value
# Out:
# garima

# %%
print(df.iat[0,0])
# Out:
# sadiksha

# %%
df
# Out:
#        name  roll  age
# 0  sadiksha     1   13
# 1    garima     2   14
# 2    binita     3   15
# 3      sita     4   23
# 4      gita     5   24

# %%
df.index
df.index=['a','b','c','d','e']
df
# Out:
#        name  roll  age
# a  sadiksha     1   13
# b    garima     2   14
# c    binita     3   15
# d      sita     4   23
# e      gita     5   24

# %%
df.axes
# Out:
# [Index(['a', 'b', 'c', 'd', 'e'], dtype='object'),
#  Index(['name', 'roll', 'age'], dtype='object')]

# %%
df.axes[0] #row names
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.axes[1]#column names
# Out:
# Index(['name', 'roll', 'age'], dtype='object')

# %%
df
# Out:
#        name  roll  age
# a  sadiksha     1   13
# b    garima     2   14
# c    binita     3   15
# d      sita     4   23
# e      gita     5   24

# %%
df.columns
# Out:
# Index(['name', 'roll', 'age'], dtype='object')

# %%
df.dtypes # returns what type od data is sorted by each columns in data frame
# Out:
# name    object
# roll     int64
# age      int64
# dtype: object

# %%
df.ndim #dimension of the dataframe
# Out:
# 2

# %%
df.shape# return number of rows and number of columns
# Out:
# (5, 3)

# %%
df.size #gives the number of elements in the data frame
# Out:
# 15

# %%
df
# Out:
#        name  roll  age
# a  sadiksha     1   13
# b    garima     2   14
# c    binita     3   15
# d      sita     4   23
# e      gita     5   24

# %%
df.values # converts the numpy dataframe into numpy array
# Out:
# array([['sadiksha', 1, 13],
#        ['garima', 2, 14],
#        ['binita', 3, 15],
#        ['sita', 4, 23],
#        ['gita', 5, 24]], dtype=object)

# %% [markdown]
# Important Methods() for DataFrame
# value_counts() – Returns how many times each unique value is repeated in a Series.
#
# df['column'].value_counts()
# to_dict() – Converts a Series or DataFrame into a Python dictionary.
#
# sort_index() – Sorts a Series or DataFrame by its index in ascending order.
#
# sort_values() – Sorts a Series or DataFrame by its values in ascending order.
#
# set_index() – Sets an existing column as the index of a DataFrame.
#
# reset_index() – Resets the index of a DataFrame and converts the index into a regular column. Creates a new DataFrame with a default index.
#
# replace() – Replaces specified values in a Series or DataFrame with other values.
#
# rename() – Renames row index labels or column labels of a Series or DataFrame.
#
# query() – Filters a DataFrame using a Boolean expression and returns a new DataFrame containing the matching rows.
#
# notna() – Returns True for non-null values and False for null values.
#
# nsmallest() – Returns the n smallest values from a Series or DataFrame.
#
# nlargest() – Returns the n largest values from a Series or DataFrame.
#
# nunique() – Counts the number of unique values present in a column.
#
# info() – Provides a concise summary of a DataFrame, including data types, non-null values, and memory usage.
#
# describe() – Generates descriptive statistics of a DataFrame, including count, mean, standard deviation, minimum, maximum, and quartile values.
#
# count() – Counts the number of non-null values in each column of a DataFrame.
#
# copy() – Creates a deep copy of a Series or DataFrame.

# %%
df['age'].value_counts()
# Out:
# age
# 13    1
# 14    1
# 15    1
# 23    1
# 24    1
# Name: count, dtype: int64

# %%
df['name'].value_counts()
# Out:
# name
# sadiksha    1
# garima      1
# binita      1
# sita        1
# gita        1
# Name: count, dtype: int64

# %%
#convert the dataframe into dictionary
df.to_dict()
# Out:
# {'name': {'a': 'sadiksha',
#   'b': 'garima',
#   'c': 'binita',
#   'd': 'sita',
#   'e': 'gita'},
#  'roll': {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5},
#  'age': {'a': 13, 'b': 14, 'c': 15, 'd': 23, 'e': 24}}

# %%
df
# Out:
#        name  roll  age
# a  sadiksha     1   13
# b    garima     2   14
# c    binita     3   15
# d      sita     4   23
# e      gita     5   24

# %%
#we can also convert dataframe into json
df.to_json('new_data.json')

# %%
df=pd.read_json("new_data.json")

# %%
df.index=['b','a','d','c','e']
df.sort_index(ascending =False)
# Out:
#        name  roll  age
# e      gita     5   24
# d    binita     3   15
# c      sita     4   23
# b  sadiksha     1   13
# a    garima     2   14

# %%
df.sort_index()
# Out:
#        name  roll  age
# a    garima     2   14
# b  sadiksha     1   13
# c      sita     4   23
# d    binita     3   15
# e      gita     5   24

# %%
#setting the existing column to index
df.set_index("age")
# Out:
#          name  roll
# age
# 13   sadiksha     1
# 14     garima     2
# 15     binita     3
# 23       sita     4
# 24       gita     5

# %%
df.set_index("roll")
# Out:
#           name  age
# roll
# 1     sadiksha   13
# 2       garima   14
# 3       binita   15
# 4         sita   23
# 5         gita   24

# %%
#reset the index to default one
df.reset_index()
# Out:
#   index      name  roll  age
# 0     b  sadiksha     1   13
# 1     a    garima     2   14
# 2     d    binita     3   15
# 3     c      sita     4   23
# 4     e      gita     5   24

# %%
df.reset_index(drop=True)# drop the extra index
# Out:
#        name  roll  age
# 0  sadiksha     1   13
# 1    garima     2   14
# 2    binita     3   15
# 3      sita     4   23
# 4      gita     5   24

# %%
#dataframe which consist nan values

data={'Name':['sadiksha',np.nan,'anu'],
     'Age':[20,22,np.nan],
     'Height':[175,162,np.nan]}
df=pd.DataFrame(data)
df
# Out:
#        Name   Age  Height
# 0  sadiksha  20.0   175.0
# 1       NaN  22.0   162.0
# 2       anu   NaN     NaN

# %%
#replace the nan value with none
df.replace(np.nan,None,inplace=True)

# %%
df
# Out:
#        Name   Age Height
# 0  sadiksha  20.0  175.0
# 1      None  22.0  162.0
# 2       anu  None   None

# %%
#replacing anu with miraj
df.replace('anu','miraj',inplace=True)

# %%
df
# Out:
#        Name   Age Height
# 0  sadiksha  20.0  175.0
# 1      None  22.0  162.0
# 2     miraj  None   None

# %%
# performing the query() function in the dataframe

# Create a sample DataFrame
data = {'Name': ['John', 'Emma', 'Michael', 'Sophia'],
'Age': [25, 28, 22, 30],
'Height': [175, 162, 180, 168]}
df = pd.DataFrame(data)
# Print the original DataFrame
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#       Name  Age  Height
# 0     John   25     175
# 1     Emma   28     162
# 2  Michael   22     180
# 3   Sophia   30     168

# %%
filtered_df1= df.query("Age>25 and Height<170")
filtered_df2=df.query("Name=='john'")
filtered_df3=df.query("Name in ['John','Emma']")# select row where name is either 'John' or'Emma'
filtered_df4 = df.query("not Height<=168") #select rows where height is not lesser equal to 168
filtered_df5= df.query("Name.str.startswith('S')")
#Print the filtered pd.DataFrame
print('\n')
print(filtered_df1)
print('\n')
print(filtered_df2)
print('\n')
print(filtered_df3)
print('\n')
print(filtered_df4)
print('\n')
print(filtered_df5)
# Out:
#      Name  Age  Height
# 1    Emma   28     162
# 3  Sophia   30     168
#
#
# Empty DataFrame
# Columns: [Name, Age, Height]
# Index: []
#
#
#    Name  Age  Height
# 0  John   25     175
# 1  Emma   28     162
#
#
#       Name  Age  Height
# 0     John   25     175
# 2  Michael   22     180
#
#
#      Name  Age  Height
# 3  Sophia   30     168

# %%
# Create a sample DataFrame with missing values
data = {'Name': ['John', np.nan, 'Michael'],
'Age': [25, np.nan, 22],
'Height': [175, 162, np.nan]}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Height
# 0     John  25.0   175.0
# 1      NaN   NaN   162.0
# 2  Michael  22.0     NaN

# %%
df['Name'].notna()
# Out:
# 0     True
# 1    False
# 2     True
# Name: Name, dtype: bool

# %%
df['Age'].notna()#return boolean value if there is value in dataframe
# Out:
# 0     True
# 1    False
# 2     True
# Name: Age, dtype: bool

# %%
df[df['Name'].notna()]
# Out:
#       Name   Age  Height
# 0     John  25.0   175.0
# 2  Michael  22.0     NaN

# %%
# just creating a data frame
dict = {'name':['miraj','sabal','sarita','rashmi','sabnam'],
'roll':[1,2,3,4,5] ,'age':[13,34,32,54,32] }
df=pd.DataFrame(dict)
df
# Out:
#      name  roll  age
# 0   miraj     1   13
# 1   sabal     2   34
# 2  sarita     3   32
# 3  rashmi     4   54
# 4  sabnam     5   32

# %%
s= df.nsmallest(2,'age')##age column ko 2 ota smallest value dinxa

# %%
l=df.nlargest(2,'age')
l
# Out:
#      name  roll  age
# 3  rashmi     4   54
# 1   sabal     2   34

# %%
df
# Out:
#      name  roll  age
# 0   miraj     1   13
# 1   sabal     2   34
# 2  sarita     3   32
# 3  rashmi     4   54
# 4  sabnam     5   32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   roll    5 non-null      int64
#  2   age     5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df.describe()
#This method generates descriptive statistics of a DataFrame,
#including count, mean, standard deviation, minimum, maximum, and quartile values.
# Out:
#            roll        age
# count  5.000000   5.000000
# mean   3.000000  33.000000
# std    1.581139  14.525839
# min    1.000000  13.000000
# 25%    2.000000  32.000000
# 50%    3.000000  32.000000
# 75%    4.000000  34.000000
# max    5.000000  54.000000

# %%
df.count()
# Out:
# name    5
# roll    5
# age     5
# dtype: int64

# %%
#copying the dataframe into m
m=df.copy()
m
# Out:
#      name  roll  age
# 0   miraj     1   13
# 1   sabal     2   34
# 2  sarita     3   32
# 3  rashmi     4   54
# 4  sabnam     5   32

# %%
df
# Out:
#      name  roll  age
# 0   miraj     1   13
# 1   sabal     2   34
# 2  sarita     3   32
# 3  rashmi     4   54
# 4  sabnam     5   32

# %%
m
# Out:
#      name  roll  age
# 0   miraj     1   13
# 1   sabal     2   34
# 2  sarita     3   32
# 3  rashmi     4   54
# 4  sabnam     5   32

# %%
df.nunique()
# Out:
# name    5
# roll    5
# age     4
# dtype: int64

# %% [markdown]
# IMP Functions, Accessing values, Slicing in data frame
