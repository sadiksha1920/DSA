# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiksha1920/DSA/blob/master/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1929609e-63cc-45ff-9f7c-5e0e4fdbae76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1929609e-63cc-45ff-9f7c-5e0e4fdbae76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
#Load CSV
df=pd.read_csv("/content/dirty_cafe_sales.csv")

print(df.head())
print(df.info())
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
# ...

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# Creating a series of pandas

# %%
s = pd.Series([10,20,30])

# %% [markdown]
# DataFrame[ task1: create a pandas dataframe with 5 column]

# %%
df1 = pd.DataFrame({
    "class 1": [85,90,75,98,95],
    "class 2": [65,78,98,88,99],
    "class 3":[80,85,67,88,99],
    "class 4":[45,67,88,97,94],
    "class 5":[87,86,95,96,97]
})

# %%
df1
# Out:
#    class 1  class 2  class 3  class 4  class 5
# 0       85       65       80       45       87
# 1       90       78       85       67       86
# 2       75       98       67       88       95
# 3       98       88       88       97       96
# 4       95       99       99       94       97

# %%
df=pd.DataFrame({
    "age":[21,22,26,24,25],
    "salary":[30000,40000,50000,10000000,550000000],
})

# %%
df
# Out:
#    age     salary
# 0   21      30000
# 1   22      40000
# 2   26      50000
# 3   24   10000000
# 4   25  550000000

# %% [markdown]
# Column Selection

# %%
df["age"]
# Out:
# 0    21
# 1    22
# 2    26
# 3    24
# 4    25
# Name: age, dtype: int64

# %%
df[["age","salary"]]
# Out:
#    age     salary
# 0   21      30000
# 1   22      40000
# 2   26      50000
# 3   24   10000000
# 4   25  550000000

# %% [markdown]
# Row Filtering

# %%
df[df["age"]>25]
# Out:
#    age  salary
# 2   26   50000

# %%
1+0
# Out:
# 1

# %%
df[(df["age"]>20) & (df["salary"]<50000)]
# Out:
#    age  salary
# 0   21   30000
# 1   22   40000

# %%
df[(df["age"]>20) | (df["salary"]<50000)]
# Out:
#    age     salary
# 0   21      30000
# 1   22      40000
# 2   26      50000
# 3   24   10000000
# 4   25  550000000

# %% [markdown]
# Insert columns

# %%
df["experience"]= [1,3,5,4,6]

# %%
df
# Out:
#    age     salary  experience
# 0   21      30000           1
# 1   22      40000           3
# 2   26      50000           5
# 3   24   10000000           4
# 4   25  550000000           6

# %%
df.dtypes
# Out:
# age           int64
# salary        int64
# experience    int64
# dtype: object

# %%
df["awards"]=[1,3,4,2,None]

# %%
df
# Out:
#    age     salary  experience  awards
# 0   21      30000           1     1.0
# 1   22      40000           3     3.0
# 2   26      50000           5     4.0
# 3   24   10000000           4     2.0
# 4   25  550000000           6     NaN

# %%
#broadcasting

df["country"]="Nepal"

# %%
df
# Out:
#    age     salary  experience  awards country
# 0   21      30000           1     1.0   Nepal
# 1   22      40000           3     3.0   Nepal
# 2   26      50000           5     4.0   Nepal
# 3   24   10000000           4     2.0   Nepal
# 4   25  550000000           6     NaN   Nepal

# %% [markdown]
# Inserting columns with missing values

# %%
import numpy as np

# %%
df["bonus"]=[5000,np.nan,70000,np.nan,np.nan]

# %%
df.head(2)
df.tail()
# Out:
#    age     salary  experience  awards country    bonus
# 0   21      30000           1     1.0   Nepal   5000.0
# 1   22      40000           3     3.0   Nepal      NaN
# 2   26      50000           5     4.0   Nepal  70000.0
# 3   24   10000000           4     2.0   Nepal      NaN
# 4   25  550000000           6     NaN   Nepal      NaN

# %%
df.tail()
# Out:
#    age     salary  experience  awards country    bonus
# 0   21      30000           1     1.0   Nepal   5000.0
# 1   22      40000           3     3.0   Nepal      NaN
# 2   26      50000           5     4.0   Nepal  70000.0
# 3   24   10000000           4     2.0   Nepal      NaN
# 4   25  550000000           6     NaN   Nepal      NaN

# %%
df1.tail()
# Out:
#    class 1  class 2  class 3  class 4  class 5
# 0       85       65       80       45       87
# 1       90       78       85       67       86
# 2       75       98       67       88       95
# 3       98       88       88       97       96
# 4       95       99       99       94       97

# %% [markdown]
# Inserting rows
#
# len(df) gives the next available index
#
# .loc[] assigns values row-wise

# %%
df.loc[len(df)] = [35,60000,3,2,'Nepal',300]

# %%
df
# Out:
#    age     salary  experience  awards country    bonus
# 0   21      30000           1     1.0   Nepal   5000.0
# 1   22      40000           3     3.0   Nepal      NaN
# 2   26      50000           5     4.0   Nepal  70000.0
# 3   24   10000000           4     2.0   Nepal      NaN
# 4   25  550000000           6     NaN   Nepal      NaN
# 5   35      60000           3     2.0   Nepal    300.0

# %% [markdown]
# Adding & Modifying Columns

# %%
df["age_squared"]=df["age"]*2

# %%
df
# Out:
#    age  monthly_salary  experience  awards country       bonus  age_squared  \
# 0   21           30000           1     1.0   Nepal      3000.0           42
# 1   22           40000           3     3.0   Nepal      4000.0           44
# 2   26           50000           5     4.0   Nepal      5000.0           52
# 3   24        10000000           4     2.0   Nepal   1000000.0           48
# 4   25       550000000           6     NaN   Nepal  55000000.0           50
# 5   35           60000           3     2.0   Nepal      6000.0           70
#
#    salary_k
# 0      30.0
# 1      40.0
# 2      50.0
# 3   10000.0
# 4  550000.0
# 5      60.0

# %%
df["bonus2"]=df["salary"]*0.01

# %%
df["salary_k"]=df["salary"]/1000

# %%
df["bonus"]=df["salary"]*0.10

# %% [markdown]
# Rename Columns

# %%
df.rename(columns={"salary": "monthly_salary"},inplace=True)

# %%
df
# Out:
#    age  monthly_salary  experience  awards country       bonus  salary_k  \
# 0   21           30000           1     1.0   Nepal      3000.0      30.0
# 1   22           40000           3     3.0   Nepal      4000.0      40.0
# 2   26           50000           5     4.0   Nepal      5000.0      50.0
# 3   24        10000000           4     2.0   Nepal   1000000.0   10000.0
# 4   25       550000000           6     NaN   Nepal  55000000.0  550000.0
# 5   35           60000           3     2.0   Nepal      6000.0      60.0
#
#    age_squared
# 0           42
# 1           44
# 2           52
# 3           48
# 4           50
# 5           70

# %%
df.drop(['age_squared'], axis=1, inplace=True)

# %%
df
# Out:
#    age  monthly_salary  experience  awards country       bonus  salary_k
# 0   21           30000           1     1.0   Nepal      3000.0      30.0
# 1   22           40000           3     3.0   Nepal      4000.0      40.0
# 2   26           50000           5     4.0   Nepal      5000.0      50.0
# 3   24        10000000           4     2.0   Nepal   1000000.0   10000.0
# 4   25       550000000           6     NaN   Nepal  55000000.0  550000.0
# 5   35           60000           3     2.0   Nepal      6000.0      60.0

# %%
df.drop(['awards', 'country'], axis=1, inplace=True)

# %%
df
# Out:
#    age  monthly_salary  experience       bonus  salary_k
# 0   21           30000           1      3000.0      30.0
# 1   22           40000           3      4000.0      40.0
# 2   26           50000           5      5000.0      50.0
# 3   24        10000000           4   1000000.0   10000.0
# 4   25       550000000           6  55000000.0  550000.0
# 5   35           60000           3      6000.0      60.0

# %% [markdown]
# Change Data Types

# %%
df["monthly_salary"] = df["monthly_salary"].astype(float)

# %%
df.dtypes
# Out:
# age                 int64
# monthly_salary    float64
# experience          int64
# bonus             float64
# salary_k          float64
# dtype: object

# %%
df
# Out:
#    age  monthly_salary  experience       bonus  salary_k
# 0   21         30000.0           1      3000.0      30.0
# 1   22         40000.0           3      4000.0      40.0
# 2   26         50000.0           5      5000.0      50.0
# 3   24      10000000.0           4   1000000.0   10000.0
# 4   25     550000000.0           6  55000000.0  550000.0
# 5   35         60000.0           3      6000.0      60.0

# %% [markdown]
# Reading Data

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3ef6949f-5356-4b2f-b55d-68aaba1978b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ef6949f-5356-4b2f-b55d-68aaba1978b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1= pd.read_csv("/content/dirty_cafe_sales.csv")

# %%
df1
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df1.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df1.tail()
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07

# %% [markdown]
# Data Inspection

# %%
df.shape

df.info()
df.columns
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             6 non-null      int64
#  1   monthly_salary  6 non-null      float64
#  2   experience      6 non-null      int64
#  3   bonus           6 non-null      float64
#  4   salary_k        6 non-null      float64
# dtypes: float64(3), int64(2)
# memory usage: 288.0 bytes
#             age  monthly_salary  experience         bonus       salary_k
# count   6.00000    6.000000e+00    6.000000  6.000000e+00       6.000000
# mean   25.50000    9.336333e+07    3.666667  9.336333e+06   93363.333333
# std     5.00999    2.237408e+08    1.751190  2.237408e+07  223740.803848
# min    21.00000    3.000000e+04    1.000000  3.000000e+03      30.000000
# 25%    22.50000    4.250000e+04    3.000000  4.250000e+03      42.500000
# ...

# %%
df1.shape
# Out:
# (10000, 8)

# %%
df1.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Transaction ID      object
# Item                object
# Quantity            object
# Price Per Unit      object
# Total Spent         object
# Payment Method      object
# Location            object
# Transaction Date    object
# dtype: object

# %% [markdown]
# handling missing values

# %%
# find missing values
df1.isna()

#sum of missing values
df1.isna().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df1
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#Drop the missing values
#df1.dropna()

# %%
df1
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#fill the missing values
df1.fillna(df1.median())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_940/1282844630.py in <cell line: 0>()
#       1 #fill the missing values
# ----> 2 df1.fillna(df1.median())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11704         **kwargs,
#   11705     ):
# > 11706         result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707         if isinstance(result, Series):
#   11708             result = result.__finalize__(self, method="median")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %% [markdown]
# Sorting and Grouping

# %%
df.sort_values(by="salary", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_940/4050923699.py in <cell line: 0>()
# ----> 1 df.sort_values(by="salary", ascending=False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'salary'

# %%
df.groupby("country")["salary"].mean()

# %% [markdown]
# Converting pandas to numpy

# %%
X = df[["age", "salary"]].values
y = df["target"].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_940/3118967446.py in <cell line: 0>()
# ----> 1 X = df[["age", "salary"]].values
#       2 y = df["target"].values
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...
