# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiksha1920/DSA/blob/master/day10_kmeans_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
X,_= make_blobs(n_samples=1000, centers=5, cluster_std=0.98)

# %%
plt.scatter(X[:,0],X[:,1],alpha=0.3)
plt.title("Scatter Plot of Data")
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
labels = kmeans.labels_

# %%
plt.scatter(X[:,0],X[:,1],c=labels,cmap='viridis',alpha=0.3)

plt.scatter(
    kmeans.cluster_centers_[:,0],
    kmeans.cluster_centers_[:,1],
    c='red',marker='X',s=200,
    label='Centroids'
)
plt.title("K-Means Clustering(k=3)")
plt.legend()
plt.show()

# %%
plt.scatter(X[:,0],X[:,1],c=labels)
plt.scatter(kmeans.cluster_centers_[:,0],
            kmeans.cluster_centers_[:,1], marker='X')
plt.title("K-Means Clustering")
plt.show()

# %%
# WINE - 3 classes, 13 features (chemical analysis)
wine = load_wine()
X, y = wine.data, wine.target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6026/930574112.py in <cell line: 0>()
#       1 # WINE - 3 classes, 13 features (chemical analysis)
# ----> 2 wine = load_wine()
#       3 X, y = wine.data, wine.target
#
# NameError: name 'load_wine' is not defined
